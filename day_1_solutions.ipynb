# %% [markdown]
# ## 1. Basic shell commands

# %% [markdown]
# a) Create a new local directory

# %%
mkdir local_dir

# %% [markdown]
# b) Create new file inside directory:

# %%
cd local_dir 
nano hello_world.py
# Out:
#   Cell In[4], line 1
#     cd local_dir
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# c) rename file

# %%
mv hello_world.py hello_world_felix.py

# %% [markdown]
# d) add print("Hello, world!") to file using 'nano hello_world_felix.py'

# %% [markdown]
# e) execute script

# %%
# !python local_dir/hello_world_felix.py
# Out:
# Hello, World!

# %% [markdown]
# f) add shebang: #!/usr/bin/env python

# %% [markdown]
# g) make executable and run without python call

# %%
# !chmod 777 local_dir/hello_world_felix.py

# %%
# !./local_dir/hello_world_felix.py
# Out:
# Hello, World!

# %% [markdown]
# h) Log in to davinci using ssh and the given password

# %% [markdown]
# i) adding ssh key to davinci using ssh-keygen, then running ssh-copy-id -i ~/.ssh/id_ed25519.pub python@davinci.icm.uu.se

# %%
# !ssh python@davinci.icm.uu.se
# Out:
# Last login: Tue Mar 17 11:36:53 2026 from 130.243.213.234
# [python@login ~]$ ^C

# %% [markdown]
# j) copy local python scripts to davinci

# %%
# !scp -r dir_felno python@davinci.icm.uu.se:/home/python/

# %% [markdown]
# k) test screen tool

# %%
screen
python slow.py # sleep for 60 seconds
# ctrl-a+d

# %% [markdown]
# # 2. Working with git

# %% [markdown]
# a) Configure local git environment

# %%
# !git config --global user.name felixnordgren11
# !git config --global user.email felix.edu.nordgren@gmail.com
# !git config --global core.editor nano

# %% [markdown]
# b) Fork and clone participants repo

# %%
# !git clone https://github.com/uu-python/participants

# %% [markdown]
# c) create file and push to remote
